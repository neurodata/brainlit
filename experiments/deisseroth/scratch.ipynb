# %%
from brainrender import Scene
from vedo import embedWindow, Plotter, show  # <- this will be used to render an embedded scene 
from itkwidgets import view

# %%
embedWindow(None)  # <- this will make your scene popup

from brainrender import Scene

popup_scene = Scene(title='popup')

popup_scene.add_brain_region('MOs')

popup_scene.render()  # press 'Esc' to close!!
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
embedWindow('k3d')  # <- this will make your scene embed with k3d


# Create a scene
scene = Scene(title='Embedded')  # note that the title will not actually display
scene.add_brain_region('MOs')

# Make sure it gets embedded in the window
scene.jupyter = True

# scene.render now will prepare the scene for rendering, but it won't render anything yet
scene.render()

#  to actually display the scene we use `vedo`'s `show` method to show the scene's actors
plt = Plotter()
plt.show(*scene.renderables)  # same as vedo.show(*scene.renderables)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/brainrender/scene.py in add(self, names, classes, transform, *items, **kwargs)
#     183             try:
# --> 184                 self.plotter.add(actor._mesh)
#     185             except AttributeError:  # e.g. for titles
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/vedo/plotter.py in add(self, actors, at, render, resetcam)
#     825         if render:
# --> 826             self.render(resetcam=resetcam)
#     827         return self
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/vedo/plotter.py in render(self, resetcam)
#     882             self.renderer.ResetCamera()
# --> 883         self.window.Render()
#     884         return self
#
# AttributeError: 'NoneType' object has no attribute 'Render'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/fq/9t66hqz51y5ddnygddgjtsmc0000gn/T/ipykernel_66983/489289779.py in <module>
#       3
#       4 # Create a scene
# ----> 5 scene = Scene(title='Embedded')  # note that the title will not actually display
#       6 scene.add_brain_region('MOs')
#       7
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/brainrender/scene.py in __init__(self, root, atlas_name, inset, title, screenshots_folder, plotter)
#      65
#      66         # Get root mesh
# ---> 67         self.root = self.add_brain_region(
#      68             "root",
#      69             alpha=settings.ROOT_ALPHA,
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/brainrender/scene.py in add_brain_region(self, alpha, color, silhouette, hemisphere, force, *regions)
#     283
#     284         # add actors
# --> 285         actors = self.add(*regions)
#     286
#     287         # slice to keep only one hemisphere
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/brainrender/scene.py in add(self, names, classes, transform, *items, **kwargs)
#     184                 self.plotter.add(actor._mesh)
#     185             except AttributeError:  # e.g. for titles
# --> 186                 self.plotter.add(actor.mesh)
#     187
#     188         # Add to the lists actors
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/vedo/plotter.py in add(self, actors, at, render, resetcam)
#     824             self.renderer.AddActor(actors)
#     825         if render:
# --> 826             self.render(resetcam=resetcam)
#     827         return self
#     828
#
# ~/Documents/mimlab/mouselight/docs_env/lib/python3.8/site-packages/vedo/plotter.py in render(self, resetcam)
#     881         if resetcam:
#     882             self.renderer.ResetCamera()
# --> 883         self.window.Render()
#     884         return self
#     885
#
# AttributeError: 'NoneType' object has no attribute 'Render'

# %%
embedWindow('itkwidgets')  # use itk widgets

# Create a scene
scene = Scene(title="brain regions", inset=False)

# Add the whole thalamus in gray
scene.add_brain_region("TH", alpha=0.15)

# Add VAL nucleus in wireframe style with the allen color
val = scene.add_brain_region("VAL")
val.wireframe()

scene.render()

view(scene.plotter.show(*scene.renderables))
# Out:
# Your scene is ready for rendering, use:
#
# from itkwidgets import view
# view(scene.plotter.show(*scene.renderables))
# Viewer(geometries=[], gradient_opacity=0.22, point_sets=[])
