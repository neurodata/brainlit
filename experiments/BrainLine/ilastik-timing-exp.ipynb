# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "/Users/thomasathey/Documents/mimlab/mouselight/brainlit_parent/brainlit/experiments/BrainLine/data/results.csv"
)

# %%
df["Processing Speed (bytes/s)"] = df["Overall Image Size"] / df["Time"]

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(yscale="log")
sns.lineplot(
    data=df,
    ax=ax,
    x="Number of Files",
    y="Processing Speed (bytes/s)",
    style="Command",
    hue="Overall Image Size",
)
# Out:
# <Axes: xlabel='Number of Files', ylabel='Processing Speed (bytes/s)'>
