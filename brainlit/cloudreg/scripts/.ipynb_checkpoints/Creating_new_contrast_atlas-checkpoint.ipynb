# %%
# %matplotlib notebook

# %%
import numpy as np
import SimpleITK as sitk
import tifffile as tf

# %%
from ARA_stuff.parse_ara import *

# %%
from scipy.ndimage import gaussian_filter

# %%
# read in atlas
atlas = sitk.GetArrayFromImage(sitk.ReadImage('../registration/atlases/average_template_50.nrrd'))
labels = sitk.GetArrayFromImage(sitk.ReadImage('../registration/atlases/annotation_50.nrrd'))

# %%
atlas.min(), atlas.max()
# Out:
# (0, 516)

# %%
tf.imshow(atlas[50,:,:], cmap='gray', vmax=255)
# Out:
# <img src="data:image/png;base64,..." width="988.5">
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x126a00430>,
#  <matplotlib.image.AxesImage at 0x128ab4c40>)

# %%
tf.imshow(labels[50,:,:], vmax=1000)
# Out:
# <img src="data:image/png;base64,..." width="988.5">
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x128df7520>,
#  <matplotlib.image.AxesImage at 0x128e53c10>)

# %%
path_to_ontology = './ARA_stuff/ara_ontology.json'
with open(path_to_ontology,'r') as fp:
        f = json.load(fp)
        tree = build_tree(f)

# %%
level1_nodes = []
get_nodes_at_level(1, tree, level1_nodes)

# %%
for i in level1_nodes:
    print(i.name)
# Out:
# Basic cell groups and regions
# fiber tracts
# ventricular systems
# grooves
# retina

# %%
level1 = get_children_dict(path_to_ontology, level=1)

# %%
mask = np.isin(labels, level1[level1_nodes[1].id]) > 0

# %%
tf.imshow(mask)
# Out:
# <img src="data:image/png;base64,..." width="988.5">
# (<Figure size 988.8x604.8 with 3 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12a754970>,
#  <matplotlib.image.AxesImage at 0x12a8521c0>)

# %%
blurred_mask = gaussian_filter(mask.astype('float'),sigma=2)

# %%
tf.imshow(blurred_mask)
# Out:
# <img src="data:image/png;base64,..." width="988.5">
# (<Figure size 988.8x604.8 with 3 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12ab6cca0>,
#  <matplotlib.image.AxesImage at 0x12aa394c0>)

# %%
tf.imshow(atlas.T, cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="988.5">
# (<Figure size 988.8x604.8 with 3 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12bb5c340>,
#  <matplotlib.image.AxesImage at 0x12bc32730>)

# %%
tf.imshow(labels[50,:,:], vmax=1000)
# Out:
# <img src="data:image/png;base64,..." width="988.5">
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12a9f1a30>,
#  <matplotlib.image.AxesImage at 0x12aaebd90>)
